# %%
### คำให้การ
### conclusion
### labels

# %%
testimony = []
conclusion = []
labels = []

# %%
y = 'คดีนี้กล่าวหาว่าตามวันเวลาเกิดเหตุ  ผู้ต้องหาได้กระทำผิดฐาน ยักยอกทรัพย์'
x = 'สอบสวน   นายวรพล  ศรีรอด  ผู้รับมอบอำนาจ   จากบริษัท  เกษตรผ่าโลกเคมีคอล  จำกัด ผู้เสียหาย  ว่ามี  นางสาวรชาดา  ปัญญา  ผู้ต้องหาที่1   ลูกจ้างทำหน้าที่พนักงานขายสินค้าและเก็บเงินค่าสินค้าของบริษัทฯได้บังอาจเบียดบังเอาสินค้าทางการเกษตร คือ ยาเสริมอาหารและบำรุงพืช ตราแอ๊ดบิ๊ก  จำนวน 30 ลัง  ราคา  140,400 บาท , สารเร่งหัวมัน ตราหัวโต จำนวน 10 ลัง ราคา43,200 บาท  และ ยาฆ่าแลง ตราแอ๊ดบา จำนวน 20 ลัง ราคา 86,400 บาท และยาคุมหญ้า ตรา แอ็ดล็อค จำนวน 20 ลัง ราคา 88,800 บาท  รวมทั้งสิ้น 358,800 บาท  ของผู้เสียหาย ไปโดยทุจริต โดยนำไปขายผู้อื่นนอกเหนือคำสั่งของผู้เสียหายแล้วไม่ชดใช้เงินให้ผู้เสียหาย  และหลบหนีไป ผู้เสียหายจึงมาร้องทุกข์ต่อพนักงานสอบสวนให้ดำเนินคดีกับ   ฐานยักยอกทรัพย์  ต่อมาหลังจับกุม ผู้ต้องหาได้พร้อมของกลาง  ผู้เสียหายยืนยันว่าของกลางเป็นของผู้เสียหาย  โดยผู้เสียหายได้รับสินค้าคืนบางส่วน    และ ผู้เสียหายทราบว่า ผู้ต้องหาที่1 นำสินค้าไปขายให้กับ นายดุสิทธิ์  จันทร์กระจ่าง ผู้ต้องหาที่2 และ นางปราณี  จันทร์กระจ่าง ผู้ต้องหาที่3 สองสามีภรรยาที่เปิดร้านค้าอยู่ที่    ร้าน อ.เกษตร 50  เลขที่ 374/2 หมู่ 8  ตำบลแพรกศรีราชา  อำเภอสรรคบุรี  จังหวัดชัยนาท และโกดังของร้านอ.เกษตร 50  ไม่ทราบเลขที่ห่างจากร้านไปประมาณ 500 เมตร หมู่ 8  ตำบลแพรกศรีราชา  อำเภอสรรคบุรี  จังหวัดชัยนาท หลังจากที่พนักงานสอบสวนไปทำการตรวจค้น โดย ผู้เสียหายยืนยันว่าไม่เคยค้าขายกับ ผู้ต้องหาที่2 และ ผู้ต้องหาที่3  มาก่อน และราคาที่ ผู้ต้องหาที่2 และ ผู้ต้องหาที่3 รับซื้อไว้ก็ต่ำกว่าความเป็นจริงที่ ผู้เสียหายเคยขายให้กับตัวแทนจำหน่าย จึงยืนยันให้ดำเนินคดีกับ ผู้ต้องหาที่2 และ ผู้ต้องหาที่3 ฐานรับของโจร'
z = ['357']

testimony.append(x)
conclusion.append(y)
labels.append(z)

# %%
data = []

for i in range(0, 39):
    xx = [testimony[i], conclusion[i], labels[i]]
    data.append(xx)

# %%
import pandas as pd

df = pd.DataFrame(data, columns=['Text','Conclusion', 'Labels'])

# %%
df.to_csv('police_record.csv')
